# %% [markdown]
# Source: https://mimic.physionet.org/tutorials/intro-to-mimic-iii/

# %%
import getpass

# %%
import pandas as pd

pd.set_option("display.max_columns", 99)

# %%
# %load_ext sql

# %%
# %config SqlMagic.autopandas=True

# %%
user = 'fehiepsi'
password = getpass.getpass()
connection_string = "postgresql://{user}:{password}@localhost/mimic3".format(user=user, password=password)
# %sql $connection_string
# %sql SET search_path TO mimiciii
del password
# Out:
# ········
# Done.

# %% [markdown]
# ### database metadata

# %%
# %%sql SELECT column_name, data_type, character_maximum_length
# FROM information_schema.columns WHERE table_name = 'admissions'
# Out:
# 19 rows affected.
#              column_name                    data_type  \
# 0                 row_id                      integer
# 1             subject_id                      integer
# 2                hadm_id                      integer
# 3              admittime  timestamp without time zone
# 4              dischtime  timestamp without time zone
# 5              deathtime  timestamp without time zone
# 6         admission_type            character varying
# 7     admission_location            character varying
# 8     discharge_location            character varying
# 9              insurance            character varying
# 10              language            character varying
# 11              religion            character varying
# 12        marital_status            character varying
# 13             ethnicity            character varying
# 14             edregtime  timestamp without time zone
# 15             edouttime  timestamp without time zone
# ...

# %%
# %%sql SELECT column_name, data_type, character_maximum_length
# FROM information_schema.columns WHERE table_name='patients'
# Out:
# 8 rows affected.
#    column_name                    data_type  character_maximum_length
# 0       row_id                      integer                       NaN
# 1   subject_id                      integer                       NaN
# 2       gender            character varying                       5.0
# 3          dob  timestamp without time zone                       NaN
# 4          dod  timestamp without time zone                       NaN
# 5     dod_hosp  timestamp without time zone                       NaN
# 6      dod_ssn  timestamp without time zone                       NaN
# 7  expire_flag                      integer                       NaN

# %%
# %%sql SELECT column_name, data_type, character_maximum_length
# FROM information_schema.columns WHERE table_name='chartevents'
# Out:
# 15 rows affected.
#      column_name                    data_type  character_maximum_length
# 0         row_id                      integer                       NaN
# 1     subject_id                      integer                       NaN
# 2        hadm_id                      integer                       NaN
# 3     icustay_id                      integer                       NaN
# 4         itemid                      integer                       NaN
# 5      charttime  timestamp without time zone                       NaN
# 6      storetime  timestamp without time zone                       NaN
# 7           cgid                      integer                       NaN
# 8          value            character varying                     255.0
# 9       valuenum             double precision                       NaN
# 10      valueuom            character varying                      50.0
# 11       warning                      integer                       NaN
# ...

# %% [markdown]
# ### patient numbers

# %%
# %%sql SELECT *
# FROM patients
# Out:
# 46520 rows affected.
#        row_id  subject_id gender        dob        dod   dod_hosp  \
# 0         234         249      F 2075-03-13        NaT        NaT
# 1         235         250      F 2164-12-27 2188-11-22 2188-11-22
# 2         236         251      M 2090-03-15        NaT        NaT
# 3         237         252      M 2078-03-06        NaT        NaT
# 4         238         253      F 2089-11-26        NaT        NaT
# 5         239         255      M 2109-08-05        NaT        NaT
# 6         240         256      M 2086-07-31        NaT        NaT
# 7         241         257      F 2031-04-03 2121-07-08 2121-07-08
# 8         242         258      F 2124-09-19        NaT        NaT
# 9         243         260      F 2105-03-23        NaT        NaT
# 10        244         261      M 2025-08-04 2102-06-29 2102-06-29
# 11        245         262      M 2090-01-05        NaT        NaT
# 12        246         263      M 2104-06-18 2168-06-13 2168-06-13
# ...

# %%
# %%sql SELECT COUNT(*)
# FROM patients
# Out:
# 1 rows affected.
#    count
# 0  46520

# %%
# %%sql SELECT DISTINCT(gender)
# FROM patients
# Out:
# 2 rows affected.
#   gender
# 0      F
# 1      M

# %%
# %%sql SELECT COUNT(*)
# FROM patients
# WHERE gender = 'F'
# Out:
# 1 rows affected.
#    count
# 0  20399

# %%
# %%sql SELECT gender, COUNT(*)
# FROM patients
# GROUP BY gender
# Out:
# 2 rows affected.
#   gender  count
# 0      F  20399
# 1      M  26121
